# %%
import json
import pandas as pd
from datetime import datetime, timedelta, date
from dateutil.parser import parse

# %%
# load fixture
with open('sample_fofixtures_1.json', 'r') as f:
    result_fofixtures = json.load(f)
if result_fofixtures:
    fixtures: list = result_fofixtures.get('fixtures', [])

fixture: dict = fixtures[0]
fixture_header: dict = fixture.get('header', {})
fixture_track: dict = fixture.get('track', {})
races: list = fixture.get('races', [])
race: dict = races[0]
entries: list = race.get('entries', [])
entry: dict = entries[0]

# %%
track_id: str = fixture_track.get('id')
track_name: str = fixture_track.get('name')
track_countryid: str = fixture_track.get('countryid')
track_countryName: str = fixture_track.get('countryName')
track_timezone: str = fixture_track.get('timezone')
track_isdst: bool = fixture_track.get('isdst')
track_timezoneOffset: int = fixture_track.get('timezoneOffset')
track_code: str = fixture_track.get('code')

print(f"{track_id}|{track_name}|{track_countryid}|{track_countryName}|{track_timezone}|{track_isdst}|{track_timezoneOffset}|{track_code}")
# Out:
# 3008|Finger Lakes|3|US|EST|True|-14400|FL

# %%
fixture_id: int = fixture_header.get('id')
fixture_date: date = parse(fixture_header.get('date')).date() if fixture_header.get('date') else None
fixture_racecount: int = fixture_header.get('racecount')
fixture_temperature: dict = fixture_header.get('temperature',{})
fixture_temperature_fahrenheit: float = fixture_temperature.get('fahrenheit')
fixture_temperature_celsius: float = fixture_temperature.get('celsius')
fixture_firstposttime: datetime = parse(fixture_header.get('firstposttime')) if fixture_header.get('firstposttime') else None

print(f"{fixture_id}|{fixture_date}|{fixture_racecount}|{fixture_temperature_fahrenheit}|{fixture_temperature_celsius}|{fixture_firstposttime}")
# Out:
# 216169|2025-06-30|8|None|None|2025-06-30 17:00:00+00:00

# %%
race_id: int = race.get('id')
race_type: str = race.get('type')
race_number: int = race.get('number')
race_runnercount: int = race.get('runnercount')
race_posttime: datetime = parse(race.get('posttime')) if race.get('posttime') else None
race_estimatedPosttime: datetime = parse(race.get('estimatedPosttime')) if race.get('estimatedPosttime') else None
race_status: str = race.get('status')
race_isdst: bool = race.get('isdst')
race_timezoneOffset: int = race.get('timezoneOffset')
race_weather: str = race.get('weather')
race_going: str = race.get('going')
race_name: str = race.get('name')
race_comment: str = race.get('comment')
race_distance: dict = race.get('distance', {})
race_distance_value: str = race_distance.get('value')
race_distance_unit: str = race_distance.get('unit')
race_distance_publishedText: str = race_distance.get('publishedText')
race_breed: str = race.get('breed')
race_racetype: dict = race.get('racetype', {})
race_racetype_type: str = race_racetype.get('type')
race_racetype_subtype: str = race_racetype.get('subtype')
race_racetype_description: str = race_racetype.get('description')
race_tracksurface: dict = race.get('tracksurface', {})
race_tracksurface_value: str = race_tracksurface.get('value')
race_tracksurface_description: str = race_tracksurface.get('description')
race_sexrestriction: dict = race.get('sexrestriction', {})
race_sexrestriction_value: str = race_sexrestriction.get('value')
race_sexrestriction_description: str = race_sexrestriction.get('description')
race_agerestriction: dict = race.get('agerestriction', {})
race_agerestriction_value: str = race_agerestriction.get('value')
race_agerestriction_description: str = race_agerestriction.get('description')
race_purse: dict = race.get('purse', {})
race_purse_value: str = race_purse.get('value')
race_purse_ranks: str = race_purse.get('ranks')
race_purse_unit: str = race_purse.get('unit')
race_grade: str = race.get('grade')
race_tip: str = race.get('raceTip')

print(f'race_id: {race_id}')
print(f'race_type: {race_type}')
print(f'race_number: {race_number}')
print(f'race_runnercount: {race_runnercount}')
print(f'race_posttime: {race_posttime}')
print(f'race_estimatedPosttime: {race_estimatedPosttime}')
print(f'race_status: {race_status}')
print(f'race_isdst: {race_isdst}')
print(f'race_timezoneOffset: {race_timezoneOffset}')
print(f'race_weather: {race_weather}')
print(f'race_going: {race_going}')
print(f'race_name: {race_name}')
print(f'race_comment: {race_comment}')
print(f'race_distance_value: {race_distance_value}')
print(f'race_distance_unit: {race_distance_unit}')
print(f'race_distance_publishedText: {race_distance_publishedText}')
print(f'race_breed: {race_breed}')
print(f'race_racetype_type: {race_racetype_type}')
print(f'race_racetype_subtype: {race_racetype_subtype}')
print(f'race_racetype_description: {race_racetype_description}')
print(f'race_tracksurface_value: {race_tracksurface_value}')
print(f'race_tracksurface_description: {race_tracksurface_description}')
print(f'race_sexrestriction_value: {race_sexrestriction_value}')
print(f'race_sexrestriction_description: {race_sexrestriction_description}')
print(f'race_agerestriction_value: {race_agerestriction_value}')
print(f'race_agerestriction_description: {race_agerestriction_description}')
print(f'race_purse_value: {race_purse_value}')
print(f'race_purse_ranks: {race_purse_ranks}')
print(f'race_purse_unit: {race_purse_unit}')
print(f'race_grade: {race_grade}')
print(f'race_tip: {race_tip}')
# Out:
# race_id: 6028936
# race_type: G
# race_number: 1
# race_runnercount: 9
# race_posttime: 2025-06-30 17:00:00+00:00
# race_estimatedPosttime: 2025-06-30 17:00:00+00:00
# race_status: WeighedIn
# race_isdst: True
# race_timezoneOffset: -14400
# race_weather: cloudy
# race_going: fast
# race_name: Race 1
# race_comment: FOR THREE YEAR OLDS AND UPWARD WHICH HAVE NOT WON A RACE SINCE DECEMBER 30, 2024 OR WHICH HAVE NEVER WON FOUR RACES OR THREE YEAR OLDS. Three Year Olds, 119 lbs.; Older, 124 lbs. Non-winners Of A Race At A Mile Or Over Since April 30 Allowed 2 lbs. Claiming Price $11,000, For Each $1,000 To $9,000 2 lbs. (Claiming Races For $5,000 Or Less Not Considered In Eligibility).
# race_distance_value: 850
# race_distance_unit: F
# race_distance_publishedText: 1 1/16 Miles
# race_breed: Thoroughbred
# race_racetype_type: CLM
# race_racetype_subtype: Flat
# race_racetype_description: CLAIMING
# race_tracksurface_value: D
# race_tracksurface_description: Dirt
# ...

# %%
{'id': '20542388',
 'startNumber': '1',
 'programNumber': '1',
 'startPosition': '3',
 'scratch_indicator': '',
 'coupledIndicator': 1,
 'decoupledNumber': '1',
 'horse_id': '1048256',
 'name': 'Thirty Oysters',
 'status': 1,
 'birthcountry': 'USA',
 'birthday': '2020-04-02',
 'age': 5,
 'saddleclothcolor': 'Red',
 'equipment': {'code': '', 'description': ''},
 'medication': {'code': 'L', 'description': 'Lasix'},
 'weight': {'value': '122',
  'overweight': None,
  'unit': 'lbs',
  'value_with_allowance': '122'},
 'breeder': 'Cedar Meadow, Inc.',
 'owner': {'id': '2317477',
  'name': 'Elizabeth D. Acree',
  'silks': 'Blue, Yellow Diamond, Blue and Yellow Striped Sleeves',
  'silksImage': 's300625/20250630xfl180001.png'},
 'trainer': {'id': '975765', 'name': 'Jose Armando Rohena'},
 'jockey': {'id': '83923',
  'name': 'Joel Cruz',
  'oldJockeyID': '',
  'oldJockeyName': ''},
 'apprenticeweight': {'value': '0', 'unit': 'lbs'},
 'flatform': '788158654404/3255213561732/732',
 'runnerTip': 'He has won three times from 6f to 1m. Beaten 1 3/4l by Brother Jeremiah when second of 6 at 15-2 on his latest outing at Finger Lakes over 1m earlier this month. Could be in the mix.',
 'forecastPrice': {'nominator': '8', 'denominator': '1'}}


entry_id: int = entry.get('id')
entry_startNumber: int = entry.get('startNumber')
entry_programNumber: int = entry.get('programNumber')
entry_startPosition: int = entry.get('startPosition')
entry_scratch_indicator: str = entry.get('scratch_indicator')
entry_coupledIndicator: int = entry.get('coupledIndicator')
entry_decoupledNumber: str = entry.get('decoupledNumber')
entry_horse_id: int = entry.get('horse_id')
entry_name: str = entry.get('name')
entry_status: int = entry.get('status')
entry_birthcountry: str = entry.get('birthcountry')
entry_birthday: datetime = parse(entry.get('birthday')) if entry.get('birthday') else None
entry_age: int = entry.get('age')
entry_saddleclothcolor: str = entry.get('saddleclothcolor')
entry_equipment: dict = entry.get('equipment', {})
entry_medication: dict = entry.get('medication', {})
entry_weight: dict = entry.get('weight', {})
entry_breeder: str = entry.get('breeder')
entry_owner: dict = entry.get('owner', {})
entry_trainer: dict = entry.get('trainer', {})
entry_jockey: dict = entry.get('jockey', {})
entry_apprenticeweight: dict = entry.get('apprenticeweight', {})
entry_flatform: str = entry.get('flatform')
entry_runnerTip: str = entry.get('runnerTip')
entry_forecastPrice: dict = entry.get('forecastPrice', {})

print(f'entry_id: {entry_id}')
print(f'entry_startNumber: {entry_startNumber}')
print(f'entry_programNumber: {entry_programNumber}')
print(f'entry_startPosition: {entry_startPosition}')
print(f'entry_scratch_indicator: {entry_scratch_indicator}')
print(f'entry_coupledIndicator: {entry_coupledIndicator}')
print(f'entry_decoupledNumber: {entry_decoupledNumber}')
print(f'entry_horse_id: {entry_horse_id}')
print(f'entry_name: {entry_name}')
print(f'entry_status: {entry_status}')
print(f'entry_birthcountry: {entry_birthcountry}')
print(f'entry_birthday: {entry_birthday}')
print(f'entry_age: {entry_age}')
print(f'entry_saddleclothcolor: {entry_saddleclothcolor}')
print(f'entry_equipment: {entry_equipment}')
print(f'entry_medication: {entry_medication}')
print(f'entry_weight: {entry_weight}')
print(f'entry_breeder: {entry_breeder}')
print(f'entry_owner: {entry_owner}')
print(f'entry_trainer: {entry_trainer}')
print(f'entry_jockey: {entry_jockey}')
print(f'entry_apprenticeweight: {entry_apprenticeweight}')
print(f'entry_flatform: {entry_flatform}')
print(f'entry_runnerTip: {entry_runnerTip}')
print(f'entry_forecastPrice: {entry_forecastPrice}')
# Out:
# entry_id: 20542388
# entry_startNumber: 1
# entry_programNumber: 1
# entry_startPosition: 3
# entry_scratch_indicator:
# entry_coupledIndicator: 1
# entry_decoupledNumber: 1
# entry_horse_id: 1048256
# entry_name: Thirty Oysters
# entry_status: 1
# entry_birthcountry: USA
# entry_birthday: 2020-04-02 00:00:00
# entry_age: 5
# entry_saddleclothcolor: Red
# entry_equipment: {'code': '', 'description': ''}
# entry_medication: {'code': 'L', 'description': 'Lasix'}
# entry_weight: {'value': '122', 'overweight': None, 'unit': 'lbs', 'value_with_allowance': '122'}
# entry_breeder: Cedar Meadow, Inc.
# entry_owner: {'id': '2317477', 'name': 'Elizabeth D. Acree', 'silks': 'Blue, Yellow Diamond, Blue and Yellow Striped Sleeves', 'silksImage': 's300625/20250630xfl180001.png'}
# entry_trainer: {'id': '975765', 'name': 'Jose Armando Rohena'}
# entry_jockey: {'id': '83923', 'name': 'Joel Cruz', 'oldJockeyID': '', 'oldJockeyName': ''}
# entry_apprenticeweight: {'value': '0', 'unit': 'lbs'}
# ...

# %% [markdown]
# # extended

# %%
race: dict = races[0] # loop
race_id: str = race.get('id')
# race_type: str = race.get('type')
race_number: str = race.get('number')
race_runnercount: int = race.get('runnercount')
race_posttime: datetime = parse(race.get('posttime')) if race.get('posttime') else None
race_estimatedPosttime: datetime = parse(race.get('estimatedPosttime')) if race.get('estimatedPosttime') else None
race_isdst: bool = race.get('isdst')
race_offTime: datetime = parse(race.get('offTime')) if race.get('offTime') else None # exclusive to race
# race_timezoneOffset: int = race.get('timezoneOffset')
race_weather: str = race.get('weather')
race_going: str = race.get('going')
race_name: str = race.get('name')
race_status: list = race.get('status') # exclusive to race
race_statusHistory: list = race.get('statusHistory') # exclusive to race
# race_comment: str = race.get('comment')
# race_distance: dict = race.get('distance', {})
# race_distance_value: str = race_distance.get('value')
# race_distance_unit: str = race_distance.get('unit')
# race_distance_publishedText: str = race_distance.get('publishedText')
# race_breed: str = race.get('breed')
# race_racetype: dict = race.get('racetype', {})
# race_racetype_type: str = race_racetype.get('type')
# race_racetype_subtype: str = race_racetype.get('subtype')
# race_racetype_description: str = race_racetype.get('description')
race_tracksurface: dict = race.get('tracksurface', {})
race_tracksurface_value: str = race_tracksurface.get('value')
# race_tracksurface_description: str = race_tracksurface.get('description')
# race_sexrestriction: dict = race.get('sexrestriction', {})
# race_sexrestriction_value: str = race_sexrestriction.get('value')
# race_sexrestriction_description: str = race_sexrestriction.get('description')
# race_agerestriction: dict = race.get('agerestriction', {})
# race_agerestriction_value: str = race_agerestriction.get('value')
# race_agerestriction_description: str = race_agerestriction.get('description')
race_overround: str = race.get('overround') # exclusientry: dict = entries[0] # loop
entry_id: int = entry.get('id')
entry_startNumber: int = entry.get('startNumber')
entry_programNumber: int = entry.get('programNumber')
entry_startPosition: int = entry.get('startPosition')
# entry_scratch_indicator: str = entry.get('scratch_indicator')
entry_coupledIndicator: int = entry.get('coupledIndicator')
entry_decoupledNumber: str = entry.get('decoupledNumber')
entry_horse_id: int = entry.get('horse_id')
entry_name: str = entry.get('name')
entry_status: int = entry.get('status')
# entry_birthcountry: str = entry.get('birthcountry')
# entry_birthday: datetime = parse(entry.get('birthday')) if entry.get('birthday') else None
# entry_age: int = entry.get('age') # NOTE: we need this info
# entry_saddleclothcolor: str = entry.get('saddleclothcolor')
entry_weight: dict = entry.get('weight', {})
entry_weight_value: int = entry_weight.get('value')
entry_weight_unit: str = entry_weight.get('unit')
entry_jockey: dict = entry.get('jockey', {})
entry_jockey_id: str = entry_jockey.get('id')
entry_jockey_name: str = entry_jockey.get('name')
entry_startingPrice: dict = entry.get('startingPrice', {})
entry_startingPrice_nominator: str = entry_startingPrice.get('nominator')
entry_startingPrice_denominator: str = entry_startingPrice.get('denominator')
entry_favPos: str = entry.get('favPos')
entry_favJoint: str = entry.get('favJoint')
entry_finalPosition: dict = entry.get('finalPosition', {})
entry_finalPosition_position: str = entry_finalPosition.get('position')
entry_finalPosition_deadHeat: str = entry_finalPosition.get('deadHeat')
entry_finalPosition_disqualified: bool = entry_finalPosition.get('disqualified')
entry_finalPosition_amendedPosition: str = entry_finalPosition.get('amendedPosition')
# entry_breeder: str = entry.get('breeder')
# entry_owner: dict = entry.get('owner', {})
# entry_trainer: dict = entry.get('trainer', {})
# entry_apprenticeweight: dict = entry.get('apprenticeweight', {})
# entry_flatform: str = entry.get('flatform')
# entry_runnerTip: str = entry.get('runnerTip')
# entry_forecastPrice: dict = entry.get('forecastPrice', {})
historical_prices: list = entry.get('showPrices', []) # NOTE: this is a list of dictsve to race
race_overround_selection: str = race.get('overround_selection') # exclusive to race
# race_purse: dict = race.get('purse', {})
# race_purse_value: str = race_purse.get('value')
# race_purse_ranks: str = race_purse.get('ranks')
# race_purse_unit: str = race_purse.get('unit')
# race_grade: str = race.get('grade')
# race_tip: str = race.get('raceTip')


entries: list = race.get('entries', [])

# %%
entry: dict = entries[0] # loop
entry_id: int = entry.get('id')
entry_startNumber: int = entry.get('startNumber')
entry_programNumber: int = entry.get('programNumber')
entry_startPosition: int = entry.get('startPosition')
# entry_scratch_indicator: str = entry.get('scratch_indicator')
entry_coupledIndicator: int = entry.get('coupledIndicator')
entry_decoupledNumber: str = entry.get('decoupledNumber')
entry_horse_id: int = entry.get('horse_id')
entry_name: str = entry.get('name')
entry_status: int = entry.get('status')
# entry_birthcountry: str = entry.get('birthcountry')
# entry_birthday: datetime = parse(entry.get('birthday')) if entry.get('birthday') else None
# entry_age: int = entry.get('age') # NOTE: we need this info
# entry_saddleclothcolor: str = entry.get('saddleclothcolor')
entry_weight: dict = entry.get('weight', {})
entry_weight_value: int = entry_weight.get('value')
entry_weight_unit: str = entry_weight.get('unit')
entry_jockey: dict = entry.get('jockey', {})
entry_jockey_id: str = entry_jockey.get('id')
entry_jockey_name: str = entry_jockey.get('name')
entry_startingPrice: dict = entry.get('startingPrice', {})
entry_startingPrice_nominator: str = entry_startingPrice.get('nominator')
entry_startingPrice_denominator: str = entry_startingPrice.get('denominator')
entry_favPos: str = entry.get('favPos')
entry_favJoint: str = entry.get('favJoint')
entry_finalPosition: dict = entry.get('finalPosition', {})
entry_finalPosition_position: str = entry_finalPosition.get('position')
entry_finalPosition_deadHeat: str = entry_finalPosition.get('deadHeat')
entry_finalPosition_disqualified: bool = entry_finalPosition.get('disqualified')
entry_finalPosition_amendedPosition: str = entry_finalPosition.get('amendedPosition')
# entry_breeder: str = entry.get('breeder')
# entry_owner: dict = entry.get('owner', {})
# entry_trainer: dict = entry.get('trainer', {})
# entry_apprenticeweight: dict = entry.get('apprenticeweight', {})
# entry_flatform: str = entry.get('flatform')
# entry_runnerTip: str = entry.get('runnerTip')
# entry_forecastPrice: dict = entry.get('forecastPrice', {})
historical_prices: list = entry.get('showPrices', []) # NOTE: this is a list of dicts
