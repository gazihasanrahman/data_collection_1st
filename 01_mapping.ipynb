# %%
import pandas as pd
from datetime import datetime, date
import traceback
from database.general import session_scope, FirstTrack, FirstFixture, FirstRace, FirstEntry, MapRace, MapRunner, MapMeeting
from utils.logger import logger_1st
from process.helper import manually_map_all_tpd_ids

# %%
manually_map_all_tpd_ids()
# Out:
# 2025-10-30 22:50:49,824 - helper.py (18) - INFO | unmapped_fixture_ids: []
# 2025-10-30 22:50:49,893 - helper.py (24) - INFO | unmapped_race_ids: []
# 2025-10-30 22:50:49,959 - helper.py (30) - INFO | unmapped_entry_ids: []
